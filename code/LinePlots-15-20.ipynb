# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.templates.default = "plotly"
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df18=pd.read_csv(f'data/2018ind.csv')
df17=pd.read_csv(f'data/2017ind.csv')
df16=pd.read_csv(f'data/2016ind.csv')
df15=pd.read_csv(f'data/2015ind.csv')
df19=pd.read_csv(f'data/2019ind.csv')
df20=pd.read_csv(f'data/2020-28thJuly_7cities.csv')

# %%
df20['Date']=pd.to_datetime(df20['Date'],format='%d/%m/%Y')
df19['Date']=pd.to_datetime(df19['Date'],format='%d/%m/%Y')
df18['Date']=pd.to_datetime(df18['Date'],format='%d/%m/%Y')
df17['Date']=pd.to_datetime(df17['Date'],format='%d/%m/%Y')
df16['Date']=pd.to_datetime(df16['Date'],format='%d/%m/%Y')
df15['Date']=pd.to_datetime(df15['Date'],format='%d/%m/%Y')

# %%
df15['md']=df15['Date'].dt.strftime('%m%d')
df15['month_name'] = df15.Date.dt.month_name()
df16['md']=df16['Date'].dt.strftime('%m%d')
df16['month_name'] = df16.Date.dt.month_name()
df17['md']=df17['Date'].dt.strftime('%m%d')
df17['month_name'] = df17.Date.dt.month_name()
df18['md']=df18['Date'].dt.strftime('%m%d')
df18['month_name'] = df18.Date.dt.month_name()
df19['md']=df19['Date'].dt.strftime('%m%d')
df19['month_name'] = df19.Date.dt.month_name()
df20['md']=df20['Date'].dt.strftime('%m%d')
df20['month_name'] = df20.Date.dt.month_name()

# %%
'''
selector=['City','Specie','md','median','Date']
df=df15[selector].merge(df16[selector],on=['City','Specie','md'])
'''
# Out:
# "\nselector=['City','Specie','md','median','Date']\ndf=df15[selector].merge(df16[selector],on=['City','Specie','md'])\n"

# %%
df=pd.concat([df15,df16,df17,df18,df19,df20])
df
# Out:
#             Date Country           City       Specie  count   min   max  \
# 0     2015-01-27      IN      Bengaluru           co      4   5.2  21.8
# 1     2015-01-28      IN      Bengaluru           co      8   7.0  37.0
# 2     2015-01-29      IN      Bengaluru           co      6   0.3   5.7
# 3     2015-02-02      IN      Bengaluru           co     16   0.6  12.7
# 4     2015-02-03      IN      Bengaluru           co      8   0.1   5.1
# ...          ...     ...            ...          ...    ...   ...   ...
# 14230 2020-07-24      IN  Visakhapatnam  temperature     24  31.3  44.6
# 14231 2020-07-25      IN  Visakhapatnam  temperature     24  31.2  31.9
# 14232 2020-07-26      IN  Visakhapatnam  temperature     24  31.2  31.9
# 14233 2020-07-27      IN  Visakhapatnam  temperature     24  31.3  33.0
# 14234 2020-07-28      IN  Visakhapatnam  temperature     12  31.5  48.5
#
#        median  variance    md month_name
# 0        12.6    461.17  0127    January
# ...

# %%
print(df.Specie.unique())
print(df.City.unique())
#pollutant=['pm25','pm10','co','so2','o3','no2']
city=['Bengaluru','Chennai','Delhi','Hyderabad','Kolkata','Mumbai','Visakhapatnam']
#df=df[df.Specie.isin(pollutant)]
df=df[df.City.isin(city)]
df
# Out:
# ['co' 'no2' 'o3' 'pm10' 'pm25' 'so2' 'humidity' 'pressure' 'temperature'
#  'wd' 'wind-gust' 'wind-speed' 'dew' 'precipitation' 'wind gust'
#  'wind speed']
# ['Bengaluru' 'Chennai' 'Delhi' 'Gandhinagar' 'Hyderabad' 'Lucknow'
#  'Mumbai' 'Kolkata' 'New Delhi' 'Chandigarh' 'Jaipur' 'Nagpur' 'Patna'
#  'Nashik' 'Visakhapatnam' 'Bhopal' 'Thiruvananthapuram' 'Gh鑶﹝i鑶゜鑶ヾ'
#  'Gh閼讹節i閼躲倻閼躲兙' 'H鑶﹑ur' 'H閼讹箲ur' 'Muzaffarnagar' 'Mysore' 'Shillong'
#  'Thrissur']
#             Date Country           City       Specie  count   min   max  \
# 0     2015-01-27      IN      Bengaluru           co      4   5.2  21.8
# 1     2015-01-28      IN      Bengaluru           co      8   7.0  37.0
# 2     2015-01-29      IN      Bengaluru           co      6   0.3   5.7
# 3     2015-02-02      IN      Bengaluru           co     16   0.6  12.7
# 4     2015-02-03      IN      Bengaluru           co      8   0.1   5.1
# ...          ...     ...            ...          ...    ...   ...   ...
# ...

# %%
df15 = df[df['Date'].dt.year == 2015]
df16 = df[df['Date'].dt.year == 2016]
df17 = df[df['Date'].dt.year == 2017]
df18 = df[df['Date'].dt.year == 2018]
df19 = df[df['Date'].dt.year == 2019]
df20 = df[df['Date'].dt.year == 2020]

# %%
print(df.Specie.unique())
print(df.City.unique())
# Out:
# ['co' 'no2' 'o3' 'pm10' 'pm25' 'so2' 'humidity' 'pressure' 'temperature'
#  'wd' 'wind-gust' 'wind-speed' 'dew' 'precipitation' 'wind gust'
#  'wind speed']
# ['Bengaluru' 'Chennai' 'Delhi' 'Hyderabad' 'Mumbai' 'Kolkata'
#  'Visakhapatnam']

# %%
df25=df[df['Specie'].isin(['pm25'])]

# %%
px.line(df25,'Date','median',color='City')

# %%
df10=df[df['Specie'].isin(['pm10'])]
px.line(df10,'Date','median',color='City')

# %%
dfh=(df[df['Specie'].isin(['temperature'])])
px.line(dfh,'Date','median',color='City')

# %%
df=df.drop_duplicates()
dfp = df.pivot_table(index=['City', 'Date'], columns='Specie')
dfp = df.set_index(['Date', 'City', 'Specie'])['median'].unstack().reset_index()

# %%
dfp
# Out:
# Specie       Date           City    co   dew  humidity   no2    o3   pm10  \
# 0      2015-01-01      Bengaluru   NaN   NaN       NaN   4.6   NaN    NaN
# 1      2015-01-01        Chennai  10.9   NaN       NaN   5.5   1.6   29.0
# 2      2015-01-01          Delhi  20.8   NaN       NaN  66.5   5.2  230.0
# 3      2015-01-01        Kolkata   NaN   NaN       NaN   NaN   NaN    NaN
# 4      2015-01-01         Mumbai   NaN   NaN       NaN   NaN   NaN    NaN
# ...           ...            ...   ...   ...       ...   ...   ...    ...
# 8634   2020-07-28          Delhi   5.4  28.0      69.4   7.0   5.5   52.0
# 8635   2020-07-28      Hyderabad   2.2  24.0      79.0   9.3   7.2   26.0
# 8636   2020-07-28        Kolkata   3.5  31.0      87.6   9.0  11.5   49.0
# 8637   2020-07-28         Mumbai   3.8  26.0      97.9   5.3   1.4   22.0
# 8638   2020-07-28  Visakhapatnam   5.9  25.5      76.5  11.4   8.3   95.0
#
# Specie   pm25  precipitation  pressure  so2  temperature  wd  wind gust  \
# ...

# %%
dfpd=dfp[dfp['City'].isin(['Delhi'])]
fig=px.line(dfpd,'Date',['no2','so2','o3'])
#fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %%
px.scatter(dfpd,'no2','so2',hover_name='Date')

# %%
px.scatter(dfpd,'no2','o3',hover_name='Date')

# %%
px.scatter(dfpd,'so2','o3',hover_name='Date')

# %%
fig=px.line(dfpd,'Date','wind-speed')
fig.show()
