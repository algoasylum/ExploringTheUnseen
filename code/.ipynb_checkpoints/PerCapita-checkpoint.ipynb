# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')

# %%
df = pd.read_csv(f'data/city_day.csv')
city = ['Bengaluru','Mumbai','Delhi','Chennai','Kolkata']
pop = [8443675,12442373,11034555,4646732,4496694]
df = df[df['City'].isin(city)]
df.Date = pd.to_datetime(df.Date,format='%Y-%m-%d')
df
# Out:
#             City       Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO  \
# 4294   Bengaluru 2015-01-01    NaN    NaN   3.26  17.33  10.88  20.36   0.33
# 4295   Bengaluru 2015-01-02    NaN    NaN   6.05  19.73  14.14  23.74   1.35
# 4296   Bengaluru 2015-01-03    NaN    NaN  11.91  19.88  20.72   4.32  17.40
# 4297   Bengaluru 2015-01-04    NaN    NaN   7.45  21.61  16.88   0.87   5.05
# 4298   Bengaluru 2015-01-05    NaN    NaN   9.52  22.17  21.76  31.38   1.83
# ...          ...        ...    ...    ...    ...    ...    ...    ...    ...
# 23859     Mumbai 2020-06-27  18.04  63.72  28.29   8.58  36.07  26.69   0.43
# 23860     Mumbai 2020-06-28  12.33  44.84  27.15   8.06  34.78  26.50   0.38
# 23861     Mumbai 2020-06-29   7.88  27.51  26.58   7.94  34.42  23.94   0.38
# 23862     Mumbai 2020-06-30   4.66  13.87  25.25   8.02  33.25  19.89   0.36
# 23863     Mumbai 2020-07-01   3.84  11.28  27.64   5.57  33.21  23.60   0.37
#
# ...

# %%
city = ['Bengaluru','Chennai','Delhi','Mumbai','Kolkata']
pop = [8443675,12442373,11034555,4646732,4496694]
pollutant =['PM2.5','PM10','NO2','SO2','CO']

# %%
# Out:
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# Bengaluru
# ...

# %%
df['perPM2.5'] = df['PM2.5']

# %%
df19 = df[df['Date'].dt.year.isin([2019])]
df20 = df[df['Date'].dt.year.isin([2020])]

# %%
fig, ax = plt.subplots(1,1,figsize=(14,10))
sns.lineplot(df19['Date'],df19['PM2.5'],hue=df['City'])
plt.show
# Out:
# /home/yash/miniconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>
