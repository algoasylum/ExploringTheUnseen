# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')
import warnings
warnings.filterwarnings('ignore')
from scipy import fftpack

# %%
dfp = pd.read_csv('data/city_hour.csv')
dfp.Datetime = pd.to_datetime(dfp.Datetime,format = '%d-%m-%Y %H:%M')
dfp.head()
# Out:
#         City            Datetime  PM2.5  PM10    NO    NO2    NOx  NH3    CO  \
# 0  Ahmedabad 2015-01-01 01:00:00    NaN   NaN  1.00  40.01  36.37  NaN  1.00
# 1  Ahmedabad 2015-01-01 02:00:00    NaN   NaN  0.02  27.75  19.73  NaN  0.02
# 2  Ahmedabad 2015-01-01 03:00:00    NaN   NaN  0.08  19.32  11.08  NaN  0.08
# 3  Ahmedabad 2015-01-01 04:00:00    NaN   NaN  0.30  16.45   9.20  NaN  0.30
# 4  Ahmedabad 2015-01-01 05:00:00    NaN   NaN  0.12  14.90   7.85  NaN  0.12
#
#       SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  122.07     NaN      0.0      0.0     0.0  NaN        NaN
# 1   85.90     NaN      0.0      0.0     0.0  NaN        NaN
# 2   52.83     NaN      0.0      0.0     0.0  NaN        NaN
# 3   39.53  153.58      0.0      0.0     0.0  NaN        NaN
# 4   32.63     NaN      0.0      0.0     0.0  NaN        NaN

# %%
dft = pd.read_csv('data/temp_hour.csv')
#del dft['Unnamed: 0']
dft.Datetime = pd.to_datetime(dft.Datetime, format = '%d-%m-%Y %H:%M')
dft.head(5)
# Out:
#         City            Datetime  maxtempC  mintempC  sunHour  DewPointC  \
# 0  Bengaluru 2009-01-01 00:00:00        27        12     11.6         16
# 1  Bengaluru 2009-01-01 01:00:00        27        12     11.6         16
# 2  Bengaluru 2009-01-01 02:00:00        27        12     11.6         15
# 3  Bengaluru 2009-01-01 03:00:00        27        12     11.6         15
# 4  Bengaluru 2009-01-01 04:00:00        27        12     11.6         15
#
#    FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 0          18          18          18            11           2        91
# 1          17          17          17             9           2        93
# 2          16          16          16             7           2        94
# 3          15          15          15             5           2        96
# 4          18          18          18             5           1        88
#
#    precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph
# 0       0.0      1014     14          10            109              8
# 1       0.0      1014     14           7             85              6
# 2       0.0      1014     13           5             61              4
# 3       0.0      1014     12           2             37              3
# 4       0.0      1015     14           5             45              3

# %%
df = dfp.merge(dft,on=['City','Datetime'])
df.head()
# Out:
#         City            Datetime  PM2.5  PM10    NO    NO2   NOx    NH3    CO  \
# 0  Bengaluru 2015-01-01 01:00:00    NaN   NaN  2.04  12.40  7.58  19.10  0.19
# 1  Bengaluru 2015-01-01 02:00:00    NaN   NaN  2.20  12.11  7.54  17.81  0.21
# 2  Bengaluru 2015-01-01 03:00:00    NaN   NaN  1.66  10.82  6.52  17.42  0.30
# 3  Bengaluru 2015-01-01 04:00:00    NaN   NaN  1.92  10.32  6.46  16.86  0.13
# 4  Bengaluru 2015-01-01 05:00:00    NaN   NaN  1.94   9.82  6.22  16.35  0.15
#
#     SO2  ...  WindChillC  WindGustKmph  cloudcover  humidity  precipMM  \
# 0  4.05  ...          20            14          65        91       0.0
# 1  4.23  ...          19            12          74        94       0.0
# 2  4.28  ...          19            10          83        97       0.0
# 3  4.14  ...          19             9          75        93       0.0
# 4  4.26  ...          20             9          66        90       0.0
#
#   pressure  tempC  visibility  winddirDegree  windspeedKmph
# 0     1010     19           7            141              9
# 1     1010     19           5            149              8
# 2     1010     18           2            156              6
# 3     1011     19           5            156              7
# 4     1011     20           7            155              7
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['City', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket',
#        'maxtempC', 'mintempC', 'sunHour', 'DewPointC', 'FeelsLikeC',
#        'HeatIndexC', 'WindChillC', 'WindGustKmph', 'cloudcover', 'humidity',
#        'precipMM', 'pressure', 'tempC', 'visibility', 'winddirDegree',
#        'windspeedKmph'],
#       dtype='object')

# %%
city = ['Bengaluru', 'Delhi', 'Hyderabad', 'Jaipur', 'Mumbai']

# %%
dc = df[(df.City == 'Delhi')]
dff = dc[(dc['Datetime'].dt.year == 2019) 
         & (dc['Datetime'].dt.month == 12) 
         & (dc['Datetime'].dt.day <=5)
        ]
fig,(ax1,ax2,ax3,ax4) = plt.subplots(4,1,figsize = (14,10),sharex=True,)
sns.lineplot(dff['Datetime'],dff['tempC'],hue = dff['City'],ax=ax1)
sns.lineplot(dff['Datetime'],dff['PM2.5'],hue = dff['City'],ax=ax2)
sns.lineplot(dff['Datetime'],dff['PM10'],hue = dff['City'],ax=ax3)
sns.lineplot(dff['Datetime'],dff['CO'],hue = dff['City'],ax=ax4)
#sns.lineplot(dff['Datetime'],dff['windspeedKmph'],hue = dff['City'],ax=ax5)
fig.savefig(f'images/fftlineplot.png', bbox_inches='tight')
plt.show()

# %%
dfc = dc[(dc['Datetime'].dt.year == 2019) 
         #& (dc['Datetime'].dt.month == 12)
        ]
fig,ax = plt.subplots(1,1,figsize = (14,10))
sns.scatterplot(dfc['tempC'],dfc['PM2.5'],hue=dc['City'])
plt.show()
fig.savefig(f'images/fftscatterplot.png', bbox_inches='tight')
dfc
# Out:
#         City            Datetime   PM2.5    PM10      NO    NO2     NOx  \
# 78910  Delhi 2019-01-01 00:00:00  404.66  613.38  159.92  83.82  188.26
# 78911  Delhi 2019-01-01 01:00:00  404.86  630.67  155.77  75.57  188.80
# 78912  Delhi 2019-01-01 02:00:00  408.67  613.37  143.89  71.75  169.26
# 78913  Delhi 2019-01-01 03:00:00  398.94  588.66  121.35  67.72  145.91
# 78914  Delhi 2019-01-01 04:00:00  367.65  533.44  120.03  62.67  143.87
# ...      ...                 ...     ...     ...     ...    ...     ...
# 87665  Delhi 2019-12-31 19:00:00  249.89  392.89   79.70  76.26  112.81
# 87666  Delhi 2019-12-31 20:00:00  345.79  488.60  138.83  78.97  165.88
# 87667  Delhi 2019-12-31 21:00:00  461.95  603.03  164.42  78.71  185.08
# 87668  Delhi 2019-12-31 22:00:00  531.85  628.67  204.60  79.51  207.88
# 87669  Delhi 2019-12-31 23:00:00  565.18  609.19  222.84  74.76  236.57
#
#          NH3    CO    SO2  ...  WindChillC  WindGustKmph  cloudcover  \
# 78910  60.94  4.41  18.53  ...          20             7           0
# 78911  62.60  3.96  16.95  ...          20             7           0
# 78912  63.13  3.42  15.57  ...          20             7           0
# 78913  55.74  3.21  13.77  ...          19             7           0
# 78914  55.83  2.73  13.16  ...          19             7           0
# ...      ...   ...    ...  ...         ...           ...         ...
# 87665  51.18  3.00  11.05  ...          14             9          42
# 87666  59.84  4.70  15.46  ...          13             9          48
# 87667  64.04  5.08  19.44  ...          12             9          55
# 87668  68.22  4.73  22.77  ...          11             8          39
# 87669  73.64  4.55  22.82  ...          11             8          23
#
#        humidity  precipMM pressure  tempC  visibility  winddirDegree  \
# 78910        30       0.0     1020     20          10            302
# 78911        31       0.0     1020     20          10            300
# 78912        31       0.0     1020     20          10            299
# 78913        31       0.0     1020     19          10            298
# 78914        32       0.0     1020     19          10            294
# ...         ...       ...      ...    ...         ...            ...
# 87665        27       0.0     1018     14          10            125
# 87666        28       0.0     1018     13          10            122
# 87667        30       0.0     1019     12          10            120
# 87668        30       0.0     1019     12          10            116
# 87669        31       0.0     1019     11          10            113
#
#        windspeedKmph
# 78910              6
# 78911              6
# 78912              6
# 78913              6
# 78914              6
# ...              ...
# 87665              7
# 87666              6
# 87667              6
# 87668              6
# 87669              6
#
# [8760 rows x 32 columns]

# %%
dc = df[(df.City == 'Delhi')]
dff = dc[(dc['Datetime'].dt.year == 2019) 
         & (dc['Datetime'].dt.month == 12) 
         & (dc['Datetime'].dt.day <=5)
        ]
fig,(ax1,ax2,ax3,ax4,ax5) = plt.subplots(5,1,figsize = (18,14),sharex=True,sharey=True)
sns.lineplot(dff['Datetime'],dff['tempC'],hue = dff['City'],ax=ax1)
sns.lineplot(dff['Datetime'],dff['PM2.5'],hue = dff['City'],ax=ax2)
sns.lineplot(dff['Datetime'],dff['PM10'],hue = dff['City'],ax=ax3)
sns.lineplot(dff['Datetime'],dff['CO'],hue = dff['City'],ax=ax4)
sns.lineplot(dff['Datetime'],dff['windspeedKmph'],hue = dff['City'],ax=ax5)
plt.show()

# %%
fig,ax = plt.subplots(2,1,figsize = (18,10),sharex=True)
for i in city:
    dc = df[df.City.isin([i])]
    dff = dc[(dc['Datetime'].dt.year == 2019) 
         & (dc['Datetime'].dt.month == 12) 
         & (dc['Datetime'].dt.day <=5)
        ]
    sns.lineplot(dff['Datetime'],dff['tempC'],label = i,ax=ax[0])
    sns.lineplot(dff['Datetime'],dff['PM2.5'],label = i,ax=ax[1])
plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize = (14,6))
N = df.shape[0]
sr = 1
dfc = df[df['City'].isin(['Delhi'])]
dfc.head(2)
y = np.array(dfc['tempC'])
y = y[~np.isnan(y)]
yf = fftpack.fft(y)
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax.plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax.set_title("FFT",c='red')
fig.savefig(f'images/fftdelhitemp.png', bbox_inches='tight')

# %%
def freq(df):
    N = df.shape[0]
    y = df
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    print(yf)
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2+1]), 2.0 / N * np.abs(yf[:N//2+1])),columns=['Freq','Ampli'])
    freq_ampli = freq_ampli[1:]
    return freq_ampli 
freq_ampli1 = freq(y)
y.shape
# Out:
# [1221966.            -0.j           10628.52687922+24967.62222133j
#     2256.96607774+10725.96368668j ...   -5884.49720598-21938.59550959j
#     2256.96607774-10725.96368668j   10628.52687922-24967.62222133j]
# (43847,)

# %%
fdai = freq_ampli1.sort_values(by=['Ampli'],ascending=False)
fdai
# Out:
#            Freq     Ampli
# 5      0.000114  9.782581
# 1827   0.041668  3.753527
# 10     0.000228  3.752671
# 1      0.000023  1.237746
# 3      0.000068  1.036061
# ...         ...       ...
# 13397  0.305540  0.000053
# 14090  0.321345  0.000053
# 11902  0.271444  0.000032
# 16666  0.380094  0.000030
# 5929   0.135220  0.000016
#
# [21923 rows x 2 columns]

# %%
fig,ax = plt.subplots(1,1,figsize = (14,6))
N = df.shape[0]
sr = 1
dfc = df[df['City'].isin(['Delhi'])]
dfc.head(2)
y = np.array(dfc['PM2.5'])
y = y[~np.isnan(y)]
yf = fftpack.fft(y)
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax.plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax.set_title("FFT",c='red') 
fig.savefig(f'images/fftdelhipm25.png', bbox_inches='tight')

# %%
def freq(df):
    N = df.shape[0]
    y = df
    f = fftpack.fftfreq(len(y))
    yf = fftpack.fft(y)
    print(yf)
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2+1]), 2.0 / N * np.abs(yf[:N//2+1])),columns=['Freq','Ampli'])
    freq_ampli = freq_ampli[1:]
    return freq_ampli 
freq_ampli1 = freq(y)
y.shape
# Out:
# [5283822.84           -0.j         -194297.65161197-238193.58453412j
#   -14399.12225514 +69678.92694449j ...  -28402.48715231+120344.05082495j
#   -14399.12225514 -69678.92694449j -194297.65161197+238193.58453412j]
# (43472,)

# %%
fdai = freq_ampli1.sort_values(by=['Ampli'],ascending=False)
fdai
# Out:
#            Freq      Ampli
# 5      0.000115  79.098909
# 10     0.000230  41.313633
# 20     0.000460  17.300058
# 1812   0.041682  16.100040
# 30     0.000690  15.018520
# ...         ...        ...
# 16744  0.385167   0.003512
# 21388  0.491995   0.002431
# 13690  0.314915   0.002414
# 18711  0.430415   0.002343
# 6447   0.148302   0.002272
#
# [21736 rows x 2 columns]

# %%
fig,ax = plt.subplots(5,1,figsize = (14,14))
for l,i in enumerate(city):
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['PM2.5'])
    y = y[~np.isnan(y)]
    N = dfc.shape[0]
    T = 1.0 / N
    #x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    #xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l].set_title("{0}".format(i),c='red')

# %%
freq_ampli = freq_ampli.sort_values(by='Ampli')
freq_ampli
# Out:
#            Freq     Ampli
# 1486   0.107378  0.001124
# 12353  0.107378  0.001124
# 7586   0.451839  0.001897
# 6253   0.451839  0.001897
# 12186  0.119445  0.002108
# ...         ...       ...
# 13836  0.000217  3.964976
# 1      0.000072  4.226701
# 13838  0.000072  4.226701
# 2      0.000145  7.018626
# 13837  0.000145  7.018626
#
# [13838 rows x 2 columns]

# %%
fig,ax = plt.subplots(5,2,figsize = (18,18))
for l,i in enumerate(city):
    N = df.shape[0]
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['tempC'])
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][0].set_title("{0}".format(i),c='red')
for l,i in enumerate(city):
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['PM2.5'])
    y = y[~np.isnan(y)]
    N = dfc.shape[0]
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][1].set_title("{0}".format(i),c='red')
fig.savefig(f'images/fftall.png', bbox_inches='tight')

# %%
fig,ax = plt.subplots(5,2,figsize = (18,18))
for l,i in enumerate(city):
    N = df.shape[0]
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['tempC'])
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][0].set_title("{0}".format(i),c='red')
for l,i in enumerate(city):
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['PM10'])
    y = y[~np.isnan(y)]
    N = dfc.shape[0]
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][1].set_title("{0}".format(i),c='red')
#fig.savefig(f'images/fftall.png', bbox_inches='tight')

# %%
fig,ax = plt.subplots(5,2,figsize = (18,18))
for l,i in enumerate(city):
    N = df.shape[0]
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['tempC'])
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][0].set_title("{0}".format(i),c='red')
for l,i in enumerate(city):
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['SO2'])
    y = y[~np.isnan(y)]
    N = dfc.shape[0]
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][1].set_title("{0}".format(i),c='red')
#fig.savefig(f'images/fftall.png', bbox_inches='tight')

# %%
fig,ax = plt.subplots(5,2,figsize = (18,18))
for l,i in enumerate(city):
    N = df.shape[0]
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['tempC'])
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][0].set_title("{0}".format(i),c='red')
for l,i in enumerate(city):
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['NO2'])
    y = y[~np.isnan(y)]
    N = dfc.shape[0]
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][1].set_title("{0}".format(i),c='red')
#fig.savefig(f'images/fftall.png', bbox_inches='tight')

# %% [markdown]
# ### T = 1.0 / N
# x = np.linspace(0.0, N*T, N)
# #y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
# yf = fftpack.fft(y)
# xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
# #fig, ax = plt.subplots()
# #ax.plot(xf, 2.0/N * np.abs(yf[:N//2]))
# #plt.show()

# %%
fig,ax = plt.subplots(5,2,figsize = (18,18))
for l,i in enumerate(city):
    N = df.shape[0]
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['tempC'])
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][0].set_title("{0}".format(i),c='red')
for l,i in enumerate(city):
    sr = 1
    dfc = df[df['City'].isin([i])]
    y = np.array(dfc['CO'])
    y = y[~np.isnan(y)]
    N = dfc.shape[0]
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[l][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[l][1].set_title("{0}".format(i),c='red')
#fig.savefig(f'images/fftall.png', bbox_inches='tight')

# %%
fig,ax = plt.subplots(1,1,figsize = (14,8))
dfh = df[df.City == 'Hyderabad']
dfh =  dfh[(dfh.Datetime.dt.year==2017)]
#dfh = dfh[dfh.Datetime.dt.month == 12]
sns.lineplot(dfh.Datetime,dfh.CO)
plt.show()

# %%
dfh
# Out:
#              City            Datetime  PM2.5    PM10    NO    NO2    NOx  \
# 105152  Hyderabad 2017-01-01 00:00:00  56.00   94.00  8.30  48.10   9.88
# 105153  Hyderabad 2017-01-01 01:00:00  56.00   94.00  7.58  39.55   8.31
# 105154  Hyderabad 2017-01-01 02:00:00  56.00  104.75  7.48  45.55   9.25
# 105155  Hyderabad 2017-01-01 03:00:00  56.00  135.00  6.62  47.43   9.34
# 105156  Hyderabad 2017-01-01 04:00:00  56.00   96.75  7.12  37.45   7.84
# ...           ...                 ...    ...     ...   ...    ...    ...
# 113907  Hyderabad 2017-12-31 19:00:00  50.38  100.80  4.67  61.69  36.43
# 113908  Hyderabad 2017-12-31 20:00:00  62.67  135.80  3.13  62.90  35.73
# 113909  Hyderabad 2017-12-31 21:00:00  68.29  154.65  4.53  74.26  42.85
# 113910  Hyderabad 2017-12-31 22:00:00  69.54  159.50  5.48  73.91  43.37
# 113911  Hyderabad 2017-12-31 23:00:00  66.50  134.00  3.71  67.15  38.51
#
#           NH3    CO   SO2  ...  WindChillC  WindGustKmph  cloudcover  \
# 105152  15.50  0.38  3.95  ...          20            14           0
# 105153  16.38  0.38  5.42  ...          20            15           0
# 105154  16.22  0.35  5.95  ...          19            15           0
# 105155  16.40  0.34  5.10  ...          19            15           0
# 105156  19.60  0.31  5.40  ...          20            13           0
# ...       ...   ...   ...  ...         ...           ...         ...
# 113907  15.44  1.19  9.71  ...          24            10           5
# 113908  16.73  1.06  9.02  ...          23             9           7
# 113909  17.90  1.17  8.84  ...          22             8           8
# 113910  19.94  1.24  9.69  ...          22             7           8
# 113911  23.49  1.16  9.38  ...          22             6           9
#
#         humidity  precipMM pressure  tempC  visibility  winddirDegree  \
# 105152        72       0.0     1014     17          10            140
# 105153        75       0.0     1014     16          10            141
# 105154        79       0.0     1015     16          10            143
# 105155        82       0.0     1015     15          10            144
# 105156        78       0.0     1015     17          10            146
# ...          ...       ...      ...    ...         ...            ...
# 113907        39       0.0     1012     23          10            117
# 113908        44       0.0     1012     22          10            123
# 113909        48       0.0     1012     21          10            129
# 113910        50       0.0     1012     21          10            123
# 113911        52       0.0     1012     21          10            116
#
#         windspeedKmph
# 105152              9
# 105153              9
# 105154              9
# 105155              9
# 105156              8
# ...               ...
# 113907              8
# 113908              7
# 113909              6
# 113910              5
# 113911              5
#
# [8760 rows x 32 columns]

# %%
y = np.array(dfh.SO2)
y = y[~np.isnan(y)]
hyder = freq(y)
hyder.head(10)
# Out:
# [89145.7           -0.j         22401.55566252-12295.85759009j
#  -2249.5569857   +395.50134976j ... -3426.56559587 -7000.35997953j
#  -2249.5569857   -395.50134976j 22401.55566252+12295.85759009j]
#         Freq     Ampli
# 1   0.000122  6.215302
# 2   0.000243  0.555529
# 3   0.000365  1.895658
# 4   0.000486  0.595389
# 5   0.000608  0.717541
# 6   0.000730  1.775281
# 7   0.000851  1.663461
# 8   0.000973  0.989808
# 9   0.001094  0.733535
# 10  0.001216  0.663130

# %%
y = np.array(dfh.CO)
y = y[~np.isnan(y)]
hyder = freq(y)
hyder.head(10)
# Out:
# [2219.82        -0.j          768.06330206+502.16650516j
#   397.61313502+688.57150967j ...   39.55239205-816.59216329j
#   397.61313502-688.57150967j  768.06330206-502.16650516j]
#         Freq     Ampli
# 1   0.000115  0.210279
# 2   0.000229  0.182201
# 3   0.000344  0.187339
# 4   0.000458  0.106360
# 5   0.000573  0.058383
# 6   0.000687  0.059683
# 7   0.000802  0.044935
# 8   0.000917  0.054362
# 9   0.001031  0.050963
# 10  0.001146  0.064216

# %%
dfc = df[df.City == 'Delhi']
fig,ax = plt.subplots(3,2,figsize = (14,10)
                      ,sharey = 'col'
                     )
N = df.shape[0]
dfsummer = dfc[(dfc.Datetime.dt.month == 2) | (dfc.Datetime.dt.month == 3)|(dfc.Datetime.dt.month == 3) | (dfc.Datetime.dt.month == 4)]
dfrain = dfc[(dfc.Datetime.dt.month == 5) | (dfc.Datetime.dt.month == 6) | (dfc.Datetime.dt.month == 7) | (dfc.Datetime.dt.month == 8)|(dfc.Datetime.dt.month == 9) ]
dfwinter = dfc[(dfc.Datetime.dt.month == 10) | (dfc.Datetime.dt.month == 11) | (dfc.Datetime.dt.month == 12) | (dfc.Datetime.dt.month == 1)]
y = np.array(dfsummer['tempC'])
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[0][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax[0][0].set_title("summer",c='red')

y = np.array(dfsummer['PM2.5'])
y = y[~np.isnan(y)]
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[0][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax[0][1].set_title("summer",c='red')

y = np.array(dfrain['tempC'])
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[1][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])

y = np.array(dfrain['PM2.5'])
y = y[~np.isnan(y)]
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[1][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax[1][1].set_title("rain",c='red')

y = np.array(dfwinter['tempC'])
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[2][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])

y = np.array(dfwinter['PM2.5'])
y = y[~np.isnan(y)]
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[2][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax[2][1].set_title("winter",c='red')
# Out:
# Text(0.5, 1.0, 'winter')

# %%
dfc = df[df.City == 'Bengaluru']
fig,ax = plt.subplots(3,2,figsize = (14,10)
                      #,sharey = True
                     )
N = df.shape[0]
dfsummer = dfc[(dfc.Datetime.dt.month == 2) | (dfc.Datetime.dt.month == 3)|(dfc.Datetime.dt.month == 3) | (dfc.Datetime.dt.month == 4)]
dfrain = dfc[(dfc.Datetime.dt.month == 5) | (dfc.Datetime.dt.month == 6) | (dfc.Datetime.dt.month == 7) | (dfc.Datetime.dt.month == 8)|(dfc.Datetime.dt.month == 9) ]
dfwinter = dfc[(dfc.Datetime.dt.month == 10) | (dfc.Datetime.dt.month == 11) | (dfc.Datetime.dt.month == 12) | (dfc.Datetime.dt.month == 1)]
y = np.array(dfsummer['tempC'])
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[0][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax[0][0].set_title("summer",c='red')

y = np.array(dfsummer['PM2.5'])
y = y[~np.isnan(y)]
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[0][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax[0][1].set_title("summer",c='red')

y = np.array(dfrain['tempC'])
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[1][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])

y = np.array(dfrain['PM2.5'])
y = y[~np.isnan(y)]
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[1][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax[1][1].set_title("rain",c='red')

y = np.array(dfwinter['tempC'])
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[2][0].plot(freq_ampli['Freq'],freq_ampli['Ampli'])

y = np.array(dfwinter['PM2.5'])
y = y[~np.isnan(y)]
T = 1.0 / N
x = np.linspace(0.0, N*T, N)
yf = fftpack.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
f = fftpack.fftfreq(len(y))
freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
freq_ampli=freq_ampli.iloc[1:]
ax[2][1].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
ax[2][1].set_title("winter",c='red')
# Out:
# Text(0.5, 1.0, 'winter')

# %%
dfc = df[df.City == 'Delhi']
fig,ax = plt.subplots(12,1,figsize=(14,10))
for i in range(0,12):
    dff = dfc[dfc.Datetime.dt.month == i+1]
    y = dff['tempC']
    y = y[~np.isnan(y)]
    T = 1.0 / N
    x = np.linspace(0.0, N*T, N)
    yf = fftpack.fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
    f = fftpack.fftfreq(len(y))
    freq_ampli = pd.DataFrame(zip(np.abs(f[:N//2]),2.0/N * np.abs(yf[:N//2])),columns=['Freq','Ampli'])
    freq_ampli=freq_ampli.iloc[1:]
    ax[i].plot(freq_ampli['Freq'],freq_ampli['Ampli'])
    ax[i].set_title("rain",c='red')

# %%
df
# Out:
#              City            Datetime   PM2.5    PM10     NO    NO2    NOx  \
# 0       Bengaluru 2015-01-01 01:00:00     NaN     NaN   2.04  12.40   7.58
# 1       Bengaluru 2015-01-01 02:00:00     NaN     NaN   2.20  12.11   7.54
# 2       Bengaluru 2015-01-01 03:00:00     NaN     NaN   1.66  10.82   6.52
# 3       Bengaluru 2015-01-01 04:00:00     NaN     NaN   1.92  10.32   6.46
# 4       Bengaluru 2015-01-01 05:00:00     NaN     NaN   1.94   9.82   6.22
# ...           ...                 ...     ...     ...    ...    ...    ...
# 197658     Mumbai 2020-01-01 19:00:00   87.29  157.49   7.75  46.47  54.21
# 197659     Mumbai 2020-01-01 20:00:00   86.16  155.17  11.43  50.71  62.14
# 197660     Mumbai 2020-01-01 21:00:00   96.47  173.27  15.65  60.21  75.86
# 197661     Mumbai 2020-01-01 22:00:00  107.37  192.57  22.38  70.16  92.56
# 197662     Mumbai 2020-01-01 23:00:00  117.40  206.28  21.72  56.97  78.68
#
#           NH3    CO   SO2  ...  WindChillC  WindGustKmph  cloudcover  \
# 0       19.10  0.19  4.05  ...          20            14          65
# 1       17.81  0.21  4.23  ...          19            12          74
# 2       17.42  0.30  4.28  ...          19            10          83
# 3       16.86  0.13  4.14  ...          19             9          75
# 4       16.35  0.15  4.26  ...          20             9          66
# ...       ...   ...   ...  ...         ...           ...         ...
# 197658  16.66  0.96  7.58  ...          25            16           4
# 197659  17.22  1.07  7.20  ...          25            15           4
# 197660  17.36  1.22  7.03  ...          25            14           4
# 197661  16.99  1.35  6.96  ...          25            13           4
# 197662  17.14  1.30  7.23  ...          24            12           4
#
#         humidity  precipMM pressure  tempC  visibility  winddirDegree  \
# 0             91       0.0     1010     19           7            141
# 1             94       0.0     1010     19           5            149
# 2             97       0.0     1010     18           2            156
# 3             93       0.0     1011     19           5            156
# 4             90       0.0     1011     20           7            155
# ...          ...       ...      ...    ...         ...            ...
# 197658        64       0.0     1014     25          10            324
# 197659        65       0.0     1015     25          10            330
# 197660        67       0.0     1015     25          10            335
# 197661        66       0.0     1015     25          10            301
# 197662        66       0.0     1015     24          10            267
#
#         windspeedKmph
# 0                   9
# 1                   8
# 2                   6
# 3                   7
# 4                   7
# ...               ...
# 197658             14
# 197659             13
# 197660             13
# 197661             12
# 197662             10
#
# [197663 rows x 32 columns]
