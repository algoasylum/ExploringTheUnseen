# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rc("figure", facecolor="white")
#print(plt.style.available)
import plotly.io as pio
import seaborn as sns
sns.set(style='whitegrid')
sns.set_palette('bright')
#sns.set(rc={'figure.figsize':(10,8)})
pio.templates.default = "none"
import warnings
warnings.filterwarnings('ignore')

# %%
df = df = pd.read_csv(f'../code/data/city_day.csv')
print(df.City.unique())
print(df.columns)
df.Date = pd.to_datetime(df.Date,format='%Y-%m-%d')
# Out:
# ['Ahmedabad' 'Aizawl' 'Amaravati' 'Amritsar' 'Bengaluru' 'Bhopal'
#  'Brajrajnagar' 'Chandigarh' 'Chennai' 'Coimbatore' 'Delhi' 'Ernakulam'
#  'Gurugram' 'Guwahati' 'Hyderabad' 'Jaipur' 'Jorapokhar' 'Kochi' 'Kolkata'
#  'Lucknow' 'Mumbai' 'Patna' 'Shillong' 'Talcher' 'Thiruvananthapuram'
#  'Visakhapatnam']
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
rural = ['Aizawl','Guwahati','Shillong','Talcher','Kochi','Coimbatore']
dfr = df[df.City.isin(rural)]
dfr = dfr.reset_index()
del dfr['index']
dfr.head(3)
# Out:
#      City       Date  PM2.5   PM10    NO   NO2    NOx    NH3    CO   SO2  \
# 0  Aizawl 2020-03-11  32.69  47.91  6.99  2.85  11.93  26.64  0.60  4.53
# 1  Aizawl 2020-03-12  31.21  38.66  7.20  1.27  10.65  25.63  0.56  4.22
# 2  Aizawl 2020-03-13  38.39  46.68  7.19  0.91  10.37  29.16  0.57  4.46
#
#      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0  4.48     0.03     0.30     NaN   NaN           NaN
# 1  2.81     0.01     0.08     NaN  52.0  Satisfactory
# 2  0.18     0.00     0.00     NaN  60.0  Satisfactory

# %%
dfcity = dfr.groupby('City').mean()
dfcity.style.background_gradient(cmap='OrRd')
# Out:
# <style  type="text/css" >
#     #T_4c4b7f74_e9c1_11ea_ac9c_f894c2d5d009row0_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4c4b7f74_e9c1_11ea_ac9c_f894c2d5d009row0_col1 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4c4b7f74_e9c1_11ea_ac9c_f894c2d5d009row0_col2 {
#             background-color:  #fee9ca;
#             color:  #000000;
#         }    #T_4c4b7f74_e9c1_11ea_ac9c_f894c2d5d009row0_col3 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4c4b7f74_e9c1_11ea_ac9c_f894c2d5d009row0_col4 {
#             background-color:  #fee0b8;
#             color:  #000000;
#         }    #T_4c4b7f74_e9c1_11ea_ac9c_f894c2d5d009row0_col5 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_4c4b7f74_e9c1_11ea_ac9c_f894c2d5d009row0_col6 {
#             background-color:  #fff4e5;
#             color:  #000000;
# ...

# %%
fig, ax = plt.subplots(1,1,figsize=(14,6))
sns.lineplot(dfr['Date'],dfr['CO'],hue=dfr['City'])
plt.tight_layout()
plt.show()
