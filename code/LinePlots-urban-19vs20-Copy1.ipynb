# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.templates.default = "plotly"
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
pollutant_who = {}
pollutant_who['co']   = 0
pollutant_who['no2']  = 0
pollutant_who['o3']   = 100 ##  8-hour mean
pollutant_who['pm10'] = 50
pollutant_who['pm25'] = 25
pollutant_who['so2']  = 20  

## annual in 'industrial, residential, rural, others' areas
pollutant_naaqs = {}
pollutant_naaqs['co']   = 2   ##  8-hour mean
pollutant_naaqs['no2']  = 80
pollutant_naaqs['o3']   = 100 ##  8-hour mean
pollutant_naaqs['pm10'] = 100
pollutant_naaqs['pm25'] = 60
pollutant_naaqs['so2']  = 80  

# Dates 
start='2019-01-01'
end='2019-07-28'
pollutant_who['pm25']
# Out:
# 25

# %%
df19=pd.read_csv(f'data/2019_7cities.csv')
print(df19.City.unique())
print(df19.Specie.unique())
df19
# Out:
# ['Bengaluru' 'Chennai' 'Delhi' 'Hyderabad' 'Kolkata' 'Mumbai'
#  'Visakhapatnam']
# ['co' 'no2' 'o3' 'pm10' 'pm25' 'so2']
#              Date Country           City Specie  count  min   max  median  \
# 0      31/12/2018      IN      Bengaluru     co    205  1.0  39.5     6.7
# 1      01/01/2019      IN      Bengaluru     co    218  1.2  36.0     7.7
# 2      02/01/2019      IN      Bengaluru     co    217  0.9  35.9     7.0
# 3      03/01/2019      IN      Bengaluru     co    217  0.2  33.2     6.7
# 4      04/01/2019      IN      Bengaluru     co    206  0.1  36.0     7.8
# ...           ...     ...            ...    ...    ...  ...   ...     ...
# 15323  01/01/2020      IN  Visakhapatnam    so2     24  3.0   5.0     4.2
# 15324  02/01/2020      IN  Visakhapatnam    so2     24  1.8   7.8     4.5
# 15325  03/01/2020      IN  Visakhapatnam    so2     24  2.1   5.3     4.0
# 15326  04/01/2020      IN  Visakhapatnam    so2     24  3.5   5.8     4.9
# 15327  05/01/2020      IN  Visakhapatnam    so2     24  3.5   6.0     4.6
#
#        variance
# 0        443.53
# 1        261.60
# 2        405.96
# 3        317.93
# 4        369.57
# ...         ...
# 15323      2.25
# 15324     20.83
# 15325      8.67
# 15326      3.95
# 15327      5.28
#
# [15328 rows x 9 columns]

# %%
df20=pd.read_csv(f'data/2020_allyear.csv')
print(df20.City.unique())
pollutant=['co','no2','o3','pm10','pm25','so2']
df20=df20[df20['Specie'].isin(pollutant)]
print(df20.Specie.unique())
df20
# Out:
# ['Hyderabad' 'Delhi' 'Chennai' 'Mumbai' 'Bengaluru' 'Kolkata']
# ['co' 'so2' 'pm25' 'pm10' 'o3' 'no2']
#        Unnamed: 0        Date Country       City Specie  count  min   max  \
# 331        185704  2020-02-04      IN  Hyderabad     co     74  1.9  18.7
# 332        185705  2020-02-13      IN  Hyderabad     co     96  1.5  18.7
# 333        185706  2020-03-07      IN  Hyderabad     co     95  0.4  14.2
# 334        185707  2020-03-09      IN  Hyderabad     co     96  1.9  17.0
# 335        185708  2020-03-14      IN  Hyderabad     co    120  1.6  15.9
# ...           ...         ...     ...        ...    ...    ...  ...   ...
# 26224      133262  2020-09-30      IN    Kolkata     co    192  0.1  12.2
# 26225      133263  2020-10-21      IN    Kolkata     co    234  0.4  34.7
# 26226      133264  2020-10-24      IN    Kolkata     co    236  0.4  26.3
# 26227      133265  2020-11-15      IN    Kolkata     co    240  1.3  25.9
# 26228      133266  2020-11-16      IN    Kolkata     co    225  0.5  29.8
#
#        median  variance
# 331       4.1    132.54
# 332       5.7    138.47
# 333       4.6     80.14
# 334       4.8     89.21
# 335       4.3     64.20
# ...       ...       ...
# 26224     3.6     49.57
# 26225     3.2    173.71
# 26226     3.8    294.21
# 26227     5.2    206.37
# 26228     6.4    344.38
#
# [13927 rows x 10 columns]

# %%
df21 = pd.read_csv(f'data/2021aqi_in.csv')
print(df21.City.unique())
pollutant=['co','no2','o3','pm10','pm25','so2']
df21=df21[df21['Specie'].isin(pollutant)]
print(df21.Specie.unique())
df21
# Out:
# ['Thrissur' 'New Delhi' 'Hyderabad' 'Delhi' 'Chandigarh' 'Bhopal' 'Nagpur'
#  'Lucknow' 'Ghāziābād' 'Hāpur' 'Gandhinagar' 'Chennai' 'Nashik' 'Mysore'
#  'Visakhapatnam' 'Mumbai' 'Jaipur' 'Patna' 'Muzaffarnagar'
#  'Thiruvananthapuram' 'Bengaluru' 'Shillong' 'Kolkata']
# ['pm10' 'so2' 'no2' 'co' 'o3' 'pm25']
#        Unnamed: 0        Date Country      City Specie  count   min    max  \
# 350        199794  2021-04-04      IN  Thrissur   pm10     71   3.0   85.0
# 351        199795  2021-04-08      IN  Thrissur   pm10     52   1.0  155.0
# 352        199796  2021-04-18      IN  Thrissur   pm10     72  16.0   72.0
# 353        199797  2021-05-04      IN  Thrissur   pm10     66  10.0   55.0
# 354        199798  2021-02-17      IN  Thrissur   pm10     72  52.0  155.0
# ...           ...         ...     ...       ...    ...    ...   ...    ...
# 42707      242151  2021-06-03      IN   Kolkata    so2    193   0.7   29.4
# 42708      242152  2021-01-19      IN   Kolkata    so2    232   0.4   27.3
# 42709      242153  2021-01-29      IN   Kolkata    so2    223   2.3   63.7
# 42710      242154  2021-01-30      IN   Kolkata    so2    240   2.4   66.2
# 42711      242155  2021-02-05      IN   Kolkata    so2    236   0.8   89.4
#
#        median  variance
# 350      59.0   2651.63
# 351      35.0  12417.40
# 352      37.0   1708.64
# 353      31.0    917.22
# 354      70.0   2360.33
# ...       ...       ...
# 42707     2.6    113.04
# 42708     8.0    296.29
# 42709     8.9   1432.12
# 42710    11.5    889.34
# 42711     8.7   1847.81
#
# [22423 rows x 10 columns]

# %%
#Clean up dates
df19['Date']=pd.to_datetime(df19['Date'],format='%d/%m/%Y')
df19 = df19[df19['Date'].dt.year == 2019]
df20['Date']=pd.to_datetime(df20['Date'],format='%Y-%m-%d')
df20 = df20[df20['Date'].dt.year == 2020]
df21['Date']=pd.to_datetime(df21['Date'],format='%Y-%m-%d')
df21 = df21[df21['Date'].dt.year == 2021]

# %%
start = '2019-01-01'
end = '2019-12-30'

# %%
dff19['Month']=pd.DatetimeIndex(dff19['Date']).month
#dff19['Day']=pd.DatetimeIndex(dff19['Date']).day
df19['md']=df19['Date'].dt.strftime('%m%d')
df19['month_name'] = df19.Date.dt.month_name()
df19=df19.reset_index()
del df19['index']
df19
# Out:
# <ipython-input-39-937647353651>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-39-937647353651>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-39-937647353651>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Date Country           City Specie  count  min   max  median  \
# 0     2019-01-01      IN      Bengaluru     co    218  1.2  36.0     7.7
# 1     2019-01-02      IN      Bengaluru     co    217  0.9  35.9     7.0
# 2     2019-01-03      IN      Bengaluru     co    217  0.2  33.2     6.7
# 3     2019-01-04      IN      Bengaluru     co    206  0.1  36.0     7.8
# 4     2019-01-05      IN      Bengaluru     co    196  0.3  37.0     7.8
# ...          ...     ...            ...    ...    ...  ...   ...     ...
# 15072 2019-12-27      IN  Visakhapatnam    so2     19  0.8  10.8     4.3
# 15073 2019-12-28      IN  Visakhapatnam    so2     20  0.7   6.9     2.8
# 15074 2019-12-29      IN  Visakhapatnam    so2      5  2.3   4.9     2.9
# 15075 2019-12-30      IN  Visakhapatnam    so2     13  0.1   9.6     5.9
# 15076 2019-12-31      IN  Visakhapatnam    so2     24  2.1   5.7     4.3
#
#        variance    md month_name
# 0        261.60  0101    January
# 1        405.96  0102    January
# 2        317.93  0103    January
# 3        369.57  0104    January
# 4        270.74  0105    January
# ...         ...   ...        ...
# 15072     84.74  1227   December
# 15073     21.91  1228   December
# 15074     11.03  1229   December
# 15075    127.46  1230   December
# 15076      9.32  1231   December
#
# [15077 rows x 11 columns]

# %%
df20['md']=df20['Date'].dt.strftime('%m%d')
df20['month_name'] = df20.Date.dt.month_name()
df20=df20.reset_index()
del df20['index']

df20
# Out:
# <ipython-input-40-18d614881286>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-40-18d614881286>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Unnamed: 0       Date Country       City Specie  count  min   max  \
# 0          185704 2020-02-04      IN  Hyderabad     co     74  1.9  18.7
# 1          185705 2020-02-13      IN  Hyderabad     co     96  1.5  18.7
# 2          185706 2020-03-07      IN  Hyderabad     co     95  0.4  14.2
# 3          185707 2020-03-09      IN  Hyderabad     co     96  1.9  17.0
# 4          185708 2020-03-14      IN  Hyderabad     co    120  1.6  15.9
# ...           ...        ...     ...        ...    ...    ...  ...   ...
# 13745      133262 2020-09-30      IN    Kolkata     co    192  0.1  12.2
# 13746      133263 2020-10-21      IN    Kolkata     co    234  0.4  34.7
# 13747      133264 2020-10-24      IN    Kolkata     co    236  0.4  26.3
# 13748      133265 2020-11-15      IN    Kolkata     co    240  1.3  25.9
# 13749      133266 2020-11-16      IN    Kolkata     co    225  0.5  29.8
#
#        median  variance    md month_name
# 0         4.1    132.54  0204   February
# 1         5.7    138.47  0213   February
# 2         4.6     80.14  0307      March
# 3         4.8     89.21  0309      March
# 4         4.3     64.20  0314      March
# ...       ...       ...   ...        ...
# 13745     3.6     49.57  0930  September
# 13746     3.2    173.71  1021    October
# 13747     3.8    294.21  1024    October
# 13748     5.2    206.37  1115   November
# 13749     6.4    344.38  1116   November
#
# [13750 rows x 12 columns]

# %%
df21['md']=df21['Date'].dt.strftime('%m%d')
df21['month_name'] = df21.Date.dt.month_name()
df21=df21.reset_index()
del df21['index']

df21
# Out:
#        Unnamed: 0       Date Country      City Specie  count   min    max  \
# 0          199794 2021-04-04      IN  Thrissur   pm10     71   3.0   85.0
# 1          199795 2021-04-08      IN  Thrissur   pm10     52   1.0  155.0
# 2          199796 2021-04-18      IN  Thrissur   pm10     72  16.0   72.0
# 3          199797 2021-05-04      IN  Thrissur   pm10     66  10.0   55.0
# 4          199798 2021-02-17      IN  Thrissur   pm10     72  52.0  155.0
# ...           ...        ...     ...       ...    ...    ...   ...    ...
# 21890      242151 2021-06-03      IN   Kolkata    so2    193   0.7   29.4
# 21891      242152 2021-01-19      IN   Kolkata    so2    232   0.4   27.3
# 21892      242153 2021-01-29      IN   Kolkata    so2    223   2.3   63.7
# 21893      242154 2021-01-30      IN   Kolkata    so2    240   2.4   66.2
# 21894      242155 2021-02-05      IN   Kolkata    so2    236   0.8   89.4
#
#        median  variance    md month_name
# 0        59.0   2651.63  0404      April
# 1        35.0  12417.40  0408      April
# 2        37.0   1708.64  0418      April
# 3        31.0    917.22  0504        May
# 4        70.0   2360.33  0217   February
# ...       ...       ...   ...        ...
# 21890     2.6    113.04  0603       June
# 21891     8.0    296.29  0119    January
# 21892     8.9   1432.12  0129    January
# 21893    11.5    889.34  0130    January
# 21894     8.7   1847.81  0205   February
#
# [21895 rows x 12 columns]

# %%
if df19['md'].iloc[1] == df20['md'].iloc[1]:
    print('tes')
df19['md'].unique()
# Out:
# array(['0101', '0102', '0103', '0104', '0105', '0106', '0107', '0108',
#        '0109', '0110', '0111', '0112', '0113', '0114', '0115', '0116',
#        '0117', '0118', '0119', '0120', '0121', '0122', '0123', '0124',
#        '0125', '0126', '0127', '0128', '0129', '0130', '0131', '0201',
#        '0202', '0203', '0204', '0205', '0206', '0207', '0208', '0209',
#        '0210', '0211', '0212', '0213', '0214', '0215', '0216', '0217',
#        '0218', '0219', '0220', '0221', '0222', '0223', '0224', '0225',
#        '0226', '0227', '0228', '0301', '0302', '0303', '0304', '0305',
#        '0306', '0307', '0308', '0309', '0310', '0311', '0312', '0313',
#        '0314', '0315', '0316', '0317', '0318', '0319', '0320', '0321',
#        '0322', '0323', '0324', '0325', '0326', '0327', '0328', '0329',
#        '0330', '0331', '0401', '0402', '0403', '0404', '0405', '0406',
#        '0407', '0408', '0409', '0410', '0411', '0412', '0413', '0415',
#        '0416', '0417', '0418', '0419', '0420', '0421', '0422', '0423',
#        '0424', '0425', '0426', '0427', '0428', '0429', '0430', '0501',
#        '0502', '0503', '0504', '0505', '0506', '0507', '0508', '0509',
#        '0510', '0511', '0512', '0513', '0514', '0515', '0516', '0517',
#        '0518', '0519', '0520', '0521', '0522', '0523', '0524', '0525',
#        '0526', '0527', '0528', '0529', '0530', '0531', '0601', '0602',
#        '0603', '0604', '0605', '0606', '0607', '0608', '0609', '0610',
#        '0611', '0612', '0613', '0614', '0615', '0616', '0617', '0618',
#        '0619', '0620', '0621', '0622', '0623', '0624', '0625', '0626',
#        '0627', '0628', '0629', '0630', '0701', '0702', '0703', '0704',
#        '0705', '0706', '0707', '0708', '0709', '0710', '0711', '0712',
#        '0713', '0714', '0715', '0716', '0717', '0718', '0719', '0720',
#        '0721', '0722', '0723', '0724', '0725', '0726', '0727', '0728',
#        '0729', '0730', '0731', '0801', '0802', '0803', '0804', '0805',
#        '0806', '0807', '0808', '0809', '0810', '0811', '0812', '0813',
#        '0814', '0815', '0816', '0817', '0818', '0819', '0820', '0821',
#        '0822', '0823', '0824', '0825', '0826', '0827', '0828', '0829',
#        '0830', '0831', '0901', '0902', '0903', '0904', '0905', '0906',
#        '0907', '0908', '0909', '0910', '0911', '0912', '0913', '0914',
#        '0915', '0916', '0917', '0918', '0919', '0920', '0921', '0922',
#        '0923', '0924', '0925', '0926', '0927', '0928', '0929', '0930',
#        '1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008',
#        '1009', '1010', '1011', '1012', '1013', '1014', '1015', '1016',
#        '1017', '1018', '1019', '1020', '1021', '1022', '1023', '1024',
#        '1025', '1026', '1027', '1028', '1029', '1030', '1031', '1101',
#        '1102', '1103', '1104', '1105', '1106', '1107', '1108', '1109',
#        '1110', '1111', '1112', '1113', '1114', '1115', '1116', '1117',
#        '1118', '1119', '1120', '1121', '1122', '1123', '1124', '1125',
#        '1126', '1127', '1128', '1129', '1130', '1201', '1202', '1203',
#        '1204', '1205', '1206', '1207', '1208', '1209', '1210', '1211',
#        '1212', '1213', '1214', '1215', '1216', '1217', '1218', '1219',
#        '1220', '1221', '1222', '1223', '1224', '1225', '1226', '1227',
#        '1228', '1229', '1230', '1231'], dtype=object)

# %%
df=pd.merge(df19,df20,on=['md','City','Specie','Country'])
del df['Country'],df['count_x'],df['min_x'],df['max_x'],df['variance_x'],df['count_y'],df['min_y'],df['max_y'],df['variance_y']
df
# Out:
#           Date_x       City Specie  median_x    md month_name_x  Unnamed: 0  \
# 0     2019-01-01  Bengaluru     co       7.7  0101      January      203068
# 1     2019-01-02  Bengaluru     co       7.0  0102      January      203078
# 2     2019-01-03  Bengaluru     co       6.7  0103      January      203043
# 3     2019-01-04  Bengaluru     co       7.8  0104      January      202989
# 4     2019-01-05  Bengaluru     co       7.8  0105      January      203079
# ...          ...        ...    ...       ...   ...          ...         ...
# 13891 2019-12-27     Mumbai    so2       4.7  1227     December      125221
# 13892 2019-12-28     Mumbai    so2       4.4  1228     December      125259
# 13893 2019-12-29     Mumbai    so2       4.9  1229     December      125227
# 13894 2019-12-30     Mumbai    so2       4.5  1230     December      125292
# 13895 2019-12-31     Mumbai    so2       4.9  1231     December      125228
#
#           Date_y  median_y month_name_y
# 0     2020-01-01       9.8      January
# 1     2020-01-02       9.3      January
# 2     2020-01-03       8.0      January
# 3     2020-01-04       8.9      January
# 4     2020-01-05       8.3      January
# ...          ...       ...          ...
# 13891 2020-12-27       6.0     December
# 13892 2020-12-28       5.6     December
# 13893 2020-12-29       6.1     December
# 13894 2020-12-30       6.1     December
# 13895 2020-12-31       5.6     December
#
# [13896 rows x 10 columns]

# %%
dff = pd.merge(df,df21, on = ['md','City','Specie'])
dff
# Out:
#          Date_x       City Specie  median_x    md month_name_x  Unnamed: 0_x  \
# 0    2019-01-01  Bengaluru     co       7.7  0101      January        203068
# 1    2019-01-02  Bengaluru     co       7.0  0102      January        203078
# 2    2019-01-03  Bengaluru     co       6.7  0103      January        203043
# 3    2019-01-04  Bengaluru     co       7.8  0104      January        202989
# 4    2019-01-05  Bengaluru     co       7.8  0105      January        203079
# ...         ...        ...    ...       ...   ...          ...           ...
# 6048 2019-06-12     Mumbai    so2      11.0  0612         June         15919
# 6049 2019-06-13     Mumbai    so2      10.6  0613         June         15987
# 6050 2019-06-14     Mumbai    so2      10.9  0614         June         15968
# 6051 2019-06-15     Mumbai    so2      10.6  0615         June         15958
# 6052 2019-06-16     Mumbai    so2       9.7  0616         June         15999
#
#          Date_y  median_y month_name_y  Unnamed: 0_y       Date Country  \
# 0    2020-01-01       9.8      January        237499 2021-01-01      IN
# 1    2020-01-02       9.3      January        237439 2021-01-02      IN
# 2    2020-01-03       8.0      January        237535 2021-01-03      IN
# 3    2020-01-04       8.9      January        237500 2021-01-04      IN
# 4    2020-01-05       8.3      January        237440 2021-01-05      IN
# ...         ...       ...          ...           ...        ...     ...
# 6048 2020-06-12       3.8         June        228374 2021-06-12      IN
# 6049 2020-06-13       3.1         June        228313 2021-06-13      IN
# 6050 2020-06-14       3.5         June        228352 2021-06-14      IN
# 6051 2020-06-15       3.5         June        228261 2021-06-15      IN
# 6052 2020-06-16       3.3         June        228245 2021-06-16      IN
#
#       count  min   max  median  variance month_name
# 0       239  0.5  86.3     5.4   4854.18    January
# 1       230  0.3  86.3     5.5   3102.37    January
# 2       212  0.5  11.5     4.0     49.29    January
# 3       233  0.3  33.8     4.9    139.71    January
# 4       239  0.8  37.0     4.4    217.21    January
# ...     ...  ...   ...     ...       ...        ...
# 6048    271  0.2  24.4     5.4    280.20       June
# 6049    270  0.3  25.5     5.4    221.11       June
# 6050    252  0.2  98.1     5.4    792.93       June
# 6051    265  0.3  26.9     5.5    244.26       June
# 6052     52  0.1  13.7     5.0    165.16       June
#
# [6053 rows x 19 columns]

# %%
imp_pollutant=['pm25','pm10','co']
dff_delhi=dff[dff['City'].isin(['Delhi'])]
dff_delhi=dff_delhi[dff_delhi['Specie'].isin(imp_pollutant)]
dff_delhi
# Out:
#          Date_x   City Specie  median_x    md month_name_x  Unnamed: 0_x  \
# 346  2019-01-01  Delhi     co      17.6  0101      January        187452
# 347  2019-01-02  Delhi     co      19.9  0102      January        187436
# 348  2019-01-03  Delhi     co      18.5  0103      January        187475
# 349  2019-01-04  Delhi     co      15.0  0104      January        187455
# 350  2019-01-05  Delhi     co      15.6  0105      January        187421
# ...         ...    ...    ...       ...   ...          ...           ...
# 4491 2019-06-12  Delhi   pm25     127.0  0612         June          3864
# 4492 2019-06-13  Delhi   pm25     132.0  0613         June          3811
# 4493 2019-06-14  Delhi   pm25     127.0  0614         June          3865
# 4494 2019-06-15  Delhi   pm25     161.0  0615         June          3806
# 4495 2019-06-16  Delhi   pm25     100.0  0616         June          3836
#
#          Date_y  median_y month_name_y  Unnamed: 0_y       Date Country  \
# 346  2020-01-01      22.6      January        206041 2021-01-01      IN
# 347  2020-01-02      24.3      January        205955 2021-01-02      IN
# 348  2020-01-03      20.3      January        206021 2021-01-03      IN
# 349  2020-01-04      17.7      January        205938 2021-01-04      IN
# 350  2020-01-05      11.3      January        205922 2021-01-05      IN
# ...         ...       ...          ...           ...        ...     ...
# 4491 2020-06-12     153.0         June        206344 2021-06-12      IN
# 4492 2020-06-13     144.0         June        206273 2021-06-13      IN
# 4493 2020-06-14     152.0         June        206410 2021-06-14      IN
# 4494 2020-06-15     124.0         June        206391 2021-06-15      IN
# 4495 2020-06-16     100.0         June        206315 2021-06-16      IN
#
#       count   min    max  median  variance month_name
# 346     776   0.2   95.8    28.1   2828.46    January
# 347     790   0.1   75.8    18.2   1198.91    January
# 348     699   0.1   72.9    11.1    740.62    January
# 349     722   0.2   82.4    10.5    834.93    January
# 350     779   0.4   78.6     9.8    701.65    January
# ...     ...   ...    ...     ...       ...        ...
# 4491    861   1.0  886.0    99.0  24752.80       June
# 4492    838  21.0  900.0    99.0  41740.00       June
# 4493    853  10.0  999.0    99.0  33229.40       June
# 4494    895  16.0  184.0    95.0   9619.79       June
# 4495    171  34.0  169.0    76.0   7051.86       June
#
# [519 rows x 19 columns]

# %%
imp_pollutant=['pm25','pm10','co']
df_delhi=df[df['City'].isin(['Delhi'])]
df_delhi=df_delhi[df_delhi['Specie'].isin(imp_pollutant)]
df_delhi
# Out:
#           Date_x   City Specie  median_x    md month_name_x  Unnamed: 0  \
# 794   2019-01-01  Delhi     co      17.6  0101      January      187452
# 795   2019-01-02  Delhi     co      19.9  0102      January      187436
# 796   2019-01-03  Delhi     co      18.5  0103      January      187475
# 797   2019-01-04  Delhi     co      15.0  0104      January      187455
# 798   2019-01-05  Delhi     co      15.6  0105      January      187421
# ...          ...    ...    ...       ...   ...          ...         ...
# 10318 2019-12-27  Delhi   pm25     285.0  1227     December      112640
# 10319 2019-12-28  Delhi   pm25     328.0  1228     December      112633
# 10320 2019-12-29  Delhi   pm25     360.0  1229     December      112682
# 10321 2019-12-30  Delhi   pm25     356.0  1230     December      112659
# 10322 2019-12-31  Delhi   pm25     248.0  1231     December      112661
#
#           Date_y  median_y month_name_y
# 794   2020-01-01      22.6      January
# 795   2020-01-02      24.3      January
# 796   2020-01-03      20.3      January
# 797   2020-01-04      17.7      January
# 798   2020-01-05      11.3      January
# ...          ...       ...          ...
# 10318 2020-12-27     297.0     December
# 10319 2020-12-28     170.0     December
# 10320 2020-12-29     185.0     December
# 10321 2020-12-30     205.0     December
# 10322 2020-12-31     273.0     December
#
# [1191 rows x 10 columns]

# %%
start = '2019-01-01'
end = '2019-12-28'
fig = make_subplots(
rows=1, cols=3,
#subplot_titles=imp_pollutant,
vertical_spacing=0.05
)
for m,i in enumerate(imp_pollutant):
    dfd=df_delhi[df_delhi['Specie'].isin([i])]
    dffd = dff_delhi[dff_delhi['Specie'].isin([i])]
    #fig.add_trace(go.Scatter(x=dfd['Date_x'],y=dfd['median_x'],line_color='blue'),row=1,col=m+1)
    fig.add_trace(go.Scatter(x=dfd['Date_x'],y=dfd['median_y'],line_color='blue'),row=1,col=m+1)
    fig.update_xaxes(tickformat="%B",row=1,col=m+1)
    fig.add_shape(go.layout.Shape(type="line", x0=start, y0=pollutant_who[i], x1=end, y1=pollutant_who[i],
                                  line=dict(color='red', width=2,dash='dot'),),row=1,col=m+1)
    fig.add_shape(go.layout.Shape(type="line", x0=start, y0=pollutant_naaqs[i], x1=end, y1=pollutant_naaqs[i],
                                  line=dict(color='green', width=2,dash='dot'),),row=1,col=m+1)
    fig.update_yaxes(title=i.upper(),range=[0,dfd['median_x'].max() +dfd['median_x'].mean()/10], row=1, col=m+1)
    fig.update_xaxes(title_text="Date", row=1, col=m+1)
fig.update_layout(title='DELHI 2020',title_x=0.5,height=450,width=1300,showlegend=False)
fig.show()
#fig.write_image(f'images/19vs20_20_delhi.png')
#py.plot(fig, filename='19vs20_delhi20',auto_open=True)
# Out:
# <div>                            <div id="5699ac9d-b1e4-4287-afa7-24ea25abf331" class="plotly-graph-div" style="height:450px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5699ac9d-b1e4-4287-afa7-24ea25abf331")) {                    Plotly.newPlot(                        "5699ac9d-b1e4-4287-afa7-24ea25abf331",                        [{"line": {"color": "blue"}, "type": "scatter", "x": ["2019-01-01T00:00:00", "2019-01-02T00:00:00", "2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-05T00:00:00", "2019-01-06T00:00:00", "2019-01-07T00:00:00", "2019-01-08T00:00:00", "2019-01-09T00:00:00", "2019-01-10T00:00:00", "2019-01-11T00:00:00", "2019-01-12T00:00:00", "2019-01-13T00:00:00", "2019-01-14T00:00:00", "2019-01-15T00:00:00", "2019-01-16T00:00:00", "2019-01-17T00:00:00", "2019-01-18T00:00:00", "2019-01-19T00:00:00", "2019-01-20T00:00:00", "2019-01-21T00:00:00", "2019-01-22T00:00:00", "2019-01-23T00:00:00", "2019-01-24T00:00:00", "2019-01-25T00:00:00", "2019-01-26T00:00:00", "2019-01-27T00:00:00", "2019-01-28T00:00:00", "2019-01-29T00:00:00", "2019-01-30T00:00:00", "2019-01-31T00:00:00", "2019-02-01T00:00:00", "2019-02-02T00:00:00", "2019-02-03T00:00:00", "2019-02-04T00:00:00", "2019-02-05T00:00:00", "2019-02-06T00:00:00", "2019-02-07T00:00:00", "2019-02-08T00:00:00", "2019-02-09T00:00:00", "2019-02-10T00:00:00", "2019-02-11T00:00:00", "2019-02-12T00:00:00", "2019-02-13T00:00:00", "2019-02-14T00:00:00", "2019-02-15T00:00:00", "2019-02-16T00:00:00", "2019-02-17T00:00:00", "2019-02-18T00:00:00", "2019-02-19T00:00:00", "2019-02-20T00:00:00", "2019-02-21T00:00:00", "2019-02-22T00:00:00", "2019-02-23T00:00:00", "2019-02-24T00:00:00", "2019-02-25T00:00:00", "2019-02-26T00:00:00", "2019-02-27T00:00:00", "2019-02-28T00:00:00", "2019-03-01T00:00:00", "2019-03-02T00:00:00", "2019-03-03T00:00:00", "2019-03-04T00:00:00", "2019-03-05T00:00:00", "2019-03-06T00:00:00", "2019-03-07T00:00:00", "2019-03-08T00:00:00", "2019-03-09T00:00:00", "2019-03-10T00:00:00", "2019-03-11T00:00:00", "2019-03-12T00:00:00", "2019-03-13T00:00:00", "2019-03-14T00:00:00", "2019-03-15T00:00:00", "2019-03-16T00:00:00", "2019-03-17T00:00:00", "2019-03-18T00:00:00", "2019-03-19T00:00:00", "2019-03-20T00:00:00", "2019-03-21T00:00:00", "2019-03-22T00:00:00", "2019-03-23T00:00:00", "2019-03-24T00:00:00", "2019-03-25T00:00:00", "2019-03-26T00:00:00", "2019-03-27T00:00:00", "2019-03-28T00:00:00", "2019-03-29T00:00:00", "2019-03-30T00:00:00", "2019-03-30T00:00:00", "2019-03-31T00:00:00", "2019-03-31T00:00:00", "2019-04-01T00:00:00", "2019-04-01T00:00:00", "2019-04-02T00:00:00", "2019-04-02T00:00:00", "2019-04-03T00:00:00", "2019-04-03T00:00:00", "2019-04-04T00:00:00", "2019-04-04T00:00:00", "2019-04-05T00:00:00", "2019-04-05T00:00:00", "2019-04-06T00:00:00", "2019-04-07T00:00:00", "2019-04-08T00:00:00", "2019-04-09T00:00:00", "2019-04-10T00:00:00", "2019-04-11T00:00:00", "2019-04-12T00:00:00", "2019-04-13T00:00:00", "2019-04-15T00:00:00", "2019-04-16T00:00:00", "2019-04-17T00:00:00", "2019-04-18T00:00:00", "2019-04-19T00:00:00", "2019-04-20T00:00:00", "2019-04-21T00:00:00", "2019-04-22T00:00:00", "2019-04-23T00:00:00", "2019-04-24T00:00:00", "2019-04-25T00:00:00", "2019-04-26T00:00:00", "2019-04-27T00:00:00", "2019-04-28T00:00:00", "2019-04-29T00:00:00", "2019-04-30T00:00:00", "2019-05-01T00:00:00", "2019-05-02T00:00:00", "2019-05-03T00:00:00", "2019-05-04T00:00:00", "2019-05-05T00:00:00", "2019-05-06T00:00:00", "2019-05-07T00:00:00", "2019-05-08T00:00:00", "2019-05-09T00:00:00", "2019-05-10T00:00:00", "2019-05-11T00:00:00", "2019-05-12T00:00:00", "2019-05-13T00:00:00", "2019-05-14T00:00:00", "2019-05-15T00:00:00", "2019-05-16T00:00:00", "2019-05-17T00:00:00", "2019-05-18T00:00:00", "2019-05-19T00:00:00", "2019-05-20T00:00:00", "2019-05-21T00:00:00", "2019-05-22T00:00:00", "2019-05-2 ...

# %%
fig = make_subplots(
rows=1, cols=3,
#subplot_titles=imp_pollutant,
vertical_spacing=0.05
)
for m,i in enumerate(imp_pollutant):
    dfd=df_delhi[df_delhi['Specie'].isin([i])]
    dffd = dff_delhi[dff_delhi['Specie'].isin([i])]
    fig.add_trace(go.Scatter(x=dfd['Date_x'],y=dfd['median_x'],line_color='red'),row=1,col=m+1)
    fig.update_xaxes(tickformat="%B",row=1,col=m+1)
    fig.add_trace(go.Scatter(x=dfd['Date_x'],y=dfd['median_y'],line_color='blue'),row=1,col=m+1)
    fig.add_trace(go.Scatter(x=dffd['Date_x'],y=dffd['median'],line_color='green'),row=1,col=m+1)
    fig.add_shape(go.layout.Shape(type="line", x0=start, y0=pollutant_who[i], x1=end, y1=pollutant_who[i],
                                  line=dict(color='orange', width=2,dash='dot'),),row=1,col=m+1)
    fig.add_shape(go.layout.Shape(type="line", x0=start, y0=pollutant_naaqs[i], x1=end, y1=pollutant_naaqs[i],
                                  line=dict(color='green', width=2,dash='dot'),),row=1,col=m+1)
    fig.update_yaxes(title=i.upper(),range=[0,dfd['median_x'].max() +dfd['median_x'].mean()/10], row=1, col=m+1)
    fig.update_xaxes(title_text="Date", row=1, col=m+1)
fig.update_layout(title='DELHI 19 vs 20 v 21',title_x=0.5,height=450,width=1300,showlegend=False)
#fig.show()
#fig.write_image(f'images/19vs20_delhi.png')
# Out:
# <div>                            <div id="1291f6ce-cf3a-40f0-94e6-863e3e5883df" class="plotly-graph-div" style="height:450px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1291f6ce-cf3a-40f0-94e6-863e3e5883df")) {                    Plotly.newPlot(                        "1291f6ce-cf3a-40f0-94e6-863e3e5883df",                        [{"line": {"color": "red"}, "type": "scatter", "x": ["2019-01-01T00:00:00", "2019-01-02T00:00:00", "2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-05T00:00:00", "2019-01-06T00:00:00", "2019-01-07T00:00:00", "2019-01-08T00:00:00", "2019-01-09T00:00:00", "2019-01-10T00:00:00", "2019-01-11T00:00:00", "2019-01-12T00:00:00", "2019-01-13T00:00:00", "2019-01-14T00:00:00", "2019-01-15T00:00:00", "2019-01-16T00:00:00", "2019-01-17T00:00:00", "2019-01-18T00:00:00", "2019-01-19T00:00:00", "2019-01-20T00:00:00", "2019-01-21T00:00:00", "2019-01-22T00:00:00", "2019-01-23T00:00:00", "2019-01-24T00:00:00", "2019-01-25T00:00:00", "2019-01-26T00:00:00", "2019-01-27T00:00:00", "2019-01-28T00:00:00", "2019-01-29T00:00:00", "2019-01-30T00:00:00", "2019-01-31T00:00:00", "2019-02-01T00:00:00", "2019-02-02T00:00:00", "2019-02-03T00:00:00", "2019-02-04T00:00:00", "2019-02-05T00:00:00", "2019-02-06T00:00:00", "2019-02-07T00:00:00", "2019-02-08T00:00:00", "2019-02-09T00:00:00", "2019-02-10T00:00:00", "2019-02-11T00:00:00", "2019-02-12T00:00:00", "2019-02-13T00:00:00", "2019-02-14T00:00:00", "2019-02-15T00:00:00", "2019-02-16T00:00:00", "2019-02-17T00:00:00", "2019-02-18T00:00:00", "2019-02-19T00:00:00", "2019-02-20T00:00:00", "2019-02-21T00:00:00", "2019-02-22T00:00:00", "2019-02-23T00:00:00", "2019-02-24T00:00:00", "2019-02-25T00:00:00", "2019-02-26T00:00:00", "2019-02-27T00:00:00", "2019-02-28T00:00:00", "2019-03-01T00:00:00", "2019-03-02T00:00:00", "2019-03-03T00:00:00", "2019-03-04T00:00:00", "2019-03-05T00:00:00", "2019-03-06T00:00:00", "2019-03-07T00:00:00", "2019-03-08T00:00:00", "2019-03-09T00:00:00", "2019-03-10T00:00:00", "2019-03-11T00:00:00", "2019-03-12T00:00:00", "2019-03-13T00:00:00", "2019-03-14T00:00:00", "2019-03-15T00:00:00", "2019-03-16T00:00:00", "2019-03-17T00:00:00", "2019-03-18T00:00:00", "2019-03-19T00:00:00", "2019-03-20T00:00:00", "2019-03-21T00:00:00", "2019-03-22T00:00:00", "2019-03-23T00:00:00", "2019-03-24T00:00:00", "2019-03-25T00:00:00", "2019-03-26T00:00:00", "2019-03-27T00:00:00", "2019-03-28T00:00:00", "2019-03-29T00:00:00", "2019-03-30T00:00:00", "2019-03-30T00:00:00", "2019-03-31T00:00:00", "2019-03-31T00:00:00", "2019-04-01T00:00:00", "2019-04-01T00:00:00", "2019-04-02T00:00:00", "2019-04-02T00:00:00", "2019-04-03T00:00:00", "2019-04-03T00:00:00", "2019-04-04T00:00:00", "2019-04-04T00:00:00", "2019-04-05T00:00:00", "2019-04-05T00:00:00", "2019-04-06T00:00:00", "2019-04-07T00:00:00", "2019-04-08T00:00:00", "2019-04-09T00:00:00", "2019-04-10T00:00:00", "2019-04-11T00:00:00", "2019-04-12T00:00:00", "2019-04-13T00:00:00", "2019-04-15T00:00:00", "2019-04-16T00:00:00", "2019-04-17T00:00:00", "2019-04-18T00:00:00", "2019-04-19T00:00:00", "2019-04-20T00:00:00", "2019-04-21T00:00:00", "2019-04-22T00:00:00", "2019-04-23T00:00:00", "2019-04-24T00:00:00", "2019-04-25T00:00:00", "2019-04-26T00:00:00", "2019-04-27T00:00:00", "2019-04-28T00:00:00", "2019-04-29T00:00:00", "2019-04-30T00:00:00", "2019-05-01T00:00:00", "2019-05-02T00:00:00", "2019-05-03T00:00:00", "2019-05-04T00:00:00", "2019-05-05T00:00:00", "2019-05-06T00:00:00", "2019-05-07T00:00:00", "2019-05-08T00:00:00", "2019-05-09T00:00:00", "2019-05-10T00:00:00", "2019-05-11T00:00:00", "2019-05-12T00:00:00", "2019-05-13T00:00:00", "2019-05-14T00:00:00", "2019-05-15T00:00:00", "2019-05-16T00:00:00", "2019-05-17T00:00:00", "2019-05-18T00:00:00", "2019-05-19T00:00:00", "2019-05-20T00:00:00", "2019-05-21T00:00:00", "2019-05-22T00:00:00", "2019-05-23 ...

# %%
df_mum=df[df['City'].isin(['Mumbai'])]
dff_mum = dff[dff['City'].isin(['Mumbai'])]
fig = make_subplots(
rows=1, cols=3,
#subplot_titles=imp_pollutant,
vertical_spacing=0.05
)
for m,i in enumerate(imp_pollutant):
    dfd=df_mum[df_mum['Specie'].isin([i])]
    dffd=dff_mum[dff_mum['Specie'].isin([i])]
    fig.add_trace(go.Scatter(x=dfd['Date_x'],y=dfd['median_x'],line_color='red'),row=1,col=m+1)
    fig.update_xaxes(tickformat="%B",row=1,col=m+1)
    fig.add_trace(go.Scatter(x=dfd['Date_x'],y=dfd['median_y'],line_color='blue'),row=1,col=m+1)
    fig.add_trace(go.Scatter(x=dffd['Date_x'],y=dffd['median'],line_color='green'),row=1,col=m+1)
    fig.add_shape(go.layout.Shape(type="line", x0=start, y0=pollutant_who[i], x1=end, y1=pollutant_who[i],
                                  line=dict(color='orange', width=2,dash='dot'),),row=1,col=m+1)
    fig.add_shape(go.layout.Shape(type="line", x0=start, y0=pollutant_naaqs[i], x1=end, y1=pollutant_naaqs[i],
                                  line=dict(color='green', width=2,dash='dot'),),row=1,col=m+1)
    fig.update_yaxes(title=i.upper(),range=[0,dfd['median_x'].max() +dfd['median_x'].mean()/10], row=1, col=m+1)
    fig.update_xaxes(title_text="Date", row=1, col=m+1)
fig.update_layout(title='MUMBAI 19 vs 20',title_x=0.5,height=450,width=1300,showlegend=False)
#fig.show()
#fig.write_image(f'images/19vs20_mumbai.png')
# Out:
# <div>                            <div id="5c68dafb-42ce-4044-acfe-abfe50508d17" class="plotly-graph-div" style="height:450px; width:1300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c68dafb-42ce-4044-acfe-abfe50508d17")) {                    Plotly.newPlot(                        "5c68dafb-42ce-4044-acfe-abfe50508d17",                        [{"line": {"color": "red"}, "type": "scatter", "x": ["2019-01-01T00:00:00", "2019-01-02T00:00:00", "2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-05T00:00:00", "2019-01-06T00:00:00", "2019-01-07T00:00:00", "2019-01-08T00:00:00", "2019-01-09T00:00:00", "2019-01-10T00:00:00", "2019-01-11T00:00:00", "2019-01-12T00:00:00", "2019-01-13T00:00:00", "2019-01-14T00:00:00", "2019-01-15T00:00:00", "2019-01-16T00:00:00", "2019-01-17T00:00:00", "2019-01-18T00:00:00", "2019-01-19T00:00:00", "2019-01-20T00:00:00", "2019-01-21T00:00:00", "2019-01-22T00:00:00", "2019-01-23T00:00:00", "2019-01-24T00:00:00", "2019-01-25T00:00:00", "2019-01-26T00:00:00", "2019-01-27T00:00:00", "2019-01-28T00:00:00", "2019-01-29T00:00:00", "2019-01-30T00:00:00", "2019-01-31T00:00:00", "2019-02-01T00:00:00", "2019-02-02T00:00:00", "2019-02-03T00:00:00", "2019-02-04T00:00:00", "2019-02-05T00:00:00", "2019-02-06T00:00:00", "2019-02-07T00:00:00", "2019-02-08T00:00:00", "2019-02-09T00:00:00", "2019-02-10T00:00:00", "2019-02-11T00:00:00", "2019-02-12T00:00:00", "2019-02-13T00:00:00", "2019-02-14T00:00:00", "2019-02-15T00:00:00", "2019-02-16T00:00:00", "2019-02-17T00:00:00", "2019-02-18T00:00:00", "2019-02-19T00:00:00", "2019-02-20T00:00:00", "2019-02-21T00:00:00", "2019-02-22T00:00:00", "2019-02-23T00:00:00", "2019-02-24T00:00:00", "2019-02-25T00:00:00", "2019-02-26T00:00:00", "2019-02-27T00:00:00", "2019-02-28T00:00:00", "2019-03-01T00:00:00", "2019-03-02T00:00:00", "2019-03-03T00:00:00", "2019-03-04T00:00:00", "2019-03-05T00:00:00", "2019-03-06T00:00:00", "2019-03-07T00:00:00", "2019-03-08T00:00:00", "2019-03-09T00:00:00", "2019-03-10T00:00:00", "2019-03-11T00:00:00", "2019-03-12T00:00:00", "2019-03-13T00:00:00", "2019-03-14T00:00:00", "2019-03-15T00:00:00", "2019-03-16T00:00:00", "2019-03-17T00:00:00", "2019-03-18T00:00:00", "2019-03-19T00:00:00", "2019-03-20T00:00:00", "2019-03-21T00:00:00", "2019-03-22T00:00:00", "2019-03-23T00:00:00", "2019-03-24T00:00:00", "2019-03-25T00:00:00", "2019-03-26T00:00:00", "2019-03-27T00:00:00", "2019-03-28T00:00:00", "2019-03-29T00:00:00", "2019-03-30T00:00:00", "2019-03-30T00:00:00", "2019-03-31T00:00:00", "2019-03-31T00:00:00", "2019-04-01T00:00:00", "2019-04-01T00:00:00", "2019-04-02T00:00:00", "2019-04-02T00:00:00", "2019-04-03T00:00:00", "2019-04-03T00:00:00", "2019-04-04T00:00:00", "2019-04-04T00:00:00", "2019-04-05T00:00:00", "2019-04-05T00:00:00", "2019-04-06T00:00:00", "2019-04-07T00:00:00", "2019-04-08T00:00:00", "2019-04-09T00:00:00", "2019-04-10T00:00:00", "2019-04-11T00:00:00", "2019-04-12T00:00:00", "2019-04-13T00:00:00", "2019-04-15T00:00:00", "2019-04-16T00:00:00", "2019-04-17T00:00:00", "2019-04-18T00:00:00", "2019-04-19T00:00:00", "2019-04-20T00:00:00", "2019-04-21T00:00:00", "2019-04-22T00:00:00", "2019-04-23T00:00:00", "2019-04-24T00:00:00", "2019-04-25T00:00:00", "2019-04-26T00:00:00", "2019-04-27T00:00:00", "2019-04-28T00:00:00", "2019-04-29T00:00:00", "2019-04-30T00:00:00", "2019-05-01T00:00:00", "2019-05-02T00:00:00", "2019-05-03T00:00:00", "2019-05-04T00:00:00", "2019-05-05T00:00:00", "2019-05-06T00:00:00", "2019-05-07T00:00:00", "2019-05-08T00:00:00", "2019-05-09T00:00:00", "2019-05-10T00:00:00", "2019-05-11T00:00:00", "2019-05-12T00:00:00", "2019-05-13T00:00:00", "2019-05-14T00:00:00", "2019-05-15T00:00:00", "2019-05-16T00:00:00", "2019-05-17T00:00:00", "2019-05-18T00:00:00", "2019-05-19T00:00:00", "2019-05-20T00:00:00", "2019-05-21T00:00:00", "2019-05-22T00:00:00", "2019-05-23 ...

# %%
city=['Bengaluru','Chennai','Delhi','Hyderabad','Kolkata','Mumbai']
title=[]
[title.append(i) for i in city for _ in range(3)]
polmax=[]
for i in imp_pollutant:
    dfd=df[df['Specie'].isin([i])]
    polmax.append(dfd['median_x'].max())
fig = make_subplots(
rows=6, cols=3,
subplot_titles=title,
vertical_spacing=0.04,
horizontal_spacing=0.05
)
for n,j in enumerate(city):
    for m,i in enumerate(imp_pollutant):
        dfd=df[df['City'].isin([j])]
        dfd=dfd[dfd['Specie'].isin([i])]
        dffd=dff[dff['City'].isin([j])]
        dffd=dffd[dffd['Specie'].isin([i])]
        fig.add_trace(go.Scatter(x=dfd['Date_x'],y=dfd['median_x'],line_color='blue'),row=n+1,col=m+1)
        fig.update_xaxes(tickformat="%B",row=1,col=m+1)
        fig.add_trace(go.Scatter(x=dfd['Date_x'],y=dfd['median_y'],line_color='red'),row=n+1,col=m+1)
        fig.add_trace(go.Scatter(x=dffd['Date_x'],y=dffd['median'],line_color='green'),row=n+1,col=m+1)
        fig.add_shape(go.layout.Shape(type="line", x0=start, y0=pollutant_who[i], x1=end, y1=pollutant_who[i],
                                  line=dict(color='orange', width=2,dash='dot'),),row=n+1,col=m+1)
        fig.add_shape(go.layout.Shape(type="line", x0=start, y0=pollutant_naaqs[i], x1=end, y1=pollutant_naaqs[i],
                                  line=dict(color='green', width=2,dash='dot'),),row=n+1,col=m+1)

        fig.update_yaxes(title=i.upper(), row=n+1, col=m+1)
        fig.update_xaxes(title_text="Date", row=n+1, col=m+1)

fig.update_layout(width=1500,height=2500,showlegend=False)
fig.show()
fig.write_image(f'images/19vs20_allcities.png')
# Out:
# <div>                            <div id="51beb7c6-b7cc-494f-a61d-81a859aadabb" class="plotly-graph-div" style="height:2500px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51beb7c6-b7cc-494f-a61d-81a859aadabb")) {                    Plotly.newPlot(                        "51beb7c6-b7cc-494f-a61d-81a859aadabb",                        [{"line": {"color": "blue"}, "type": "scatter", "x": ["2019-01-01T00:00:00", "2019-01-02T00:00:00", "2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-05T00:00:00", "2019-01-06T00:00:00", "2019-01-07T00:00:00", "2019-01-08T00:00:00", "2019-01-09T00:00:00", "2019-01-10T00:00:00", "2019-01-11T00:00:00", "2019-01-12T00:00:00", "2019-01-13T00:00:00", "2019-01-14T00:00:00", "2019-01-15T00:00:00", "2019-01-16T00:00:00", "2019-01-17T00:00:00", "2019-01-18T00:00:00", "2019-01-19T00:00:00", "2019-01-20T00:00:00", "2019-01-21T00:00:00", "2019-01-22T00:00:00", "2019-01-23T00:00:00", "2019-01-24T00:00:00", "2019-01-25T00:00:00", "2019-01-26T00:00:00", "2019-01-27T00:00:00", "2019-01-28T00:00:00", "2019-01-29T00:00:00", "2019-01-30T00:00:00", "2019-01-31T00:00:00", "2019-02-01T00:00:00", "2019-02-02T00:00:00", "2019-02-03T00:00:00", "2019-02-04T00:00:00", "2019-02-05T00:00:00", "2019-02-06T00:00:00", "2019-02-07T00:00:00", "2019-02-08T00:00:00", "2019-02-09T00:00:00", "2019-02-10T00:00:00", "2019-02-11T00:00:00", "2019-02-12T00:00:00", "2019-02-13T00:00:00", "2019-02-14T00:00:00", "2019-02-15T00:00:00", "2019-02-16T00:00:00", "2019-02-17T00:00:00", "2019-02-18T00:00:00", "2019-02-19T00:00:00", "2019-02-20T00:00:00", "2019-02-21T00:00:00", "2019-02-22T00:00:00", "2019-02-23T00:00:00", "2019-02-24T00:00:00", "2019-02-25T00:00:00", "2019-02-26T00:00:00", "2019-02-27T00:00:00", "2019-02-28T00:00:00", "2019-03-01T00:00:00", "2019-03-02T00:00:00", "2019-03-03T00:00:00", "2019-03-04T00:00:00", "2019-03-05T00:00:00", "2019-03-06T00:00:00", "2019-03-07T00:00:00", "2019-03-08T00:00:00", "2019-03-09T00:00:00", "2019-03-10T00:00:00", "2019-03-11T00:00:00", "2019-03-12T00:00:00", "2019-03-13T00:00:00", "2019-03-14T00:00:00", "2019-03-15T00:00:00", "2019-03-16T00:00:00", "2019-03-17T00:00:00", "2019-03-18T00:00:00", "2019-03-19T00:00:00", "2019-03-20T00:00:00", "2019-03-21T00:00:00", "2019-03-22T00:00:00", "2019-03-23T00:00:00", "2019-03-24T00:00:00", "2019-03-25T00:00:00", "2019-03-26T00:00:00", "2019-03-27T00:00:00", "2019-03-28T00:00:00", "2019-03-29T00:00:00", "2019-03-30T00:00:00", "2019-03-30T00:00:00", "2019-03-31T00:00:00", "2019-03-31T00:00:00", "2019-04-01T00:00:00", "2019-04-01T00:00:00", "2019-04-02T00:00:00", "2019-04-02T00:00:00", "2019-04-03T00:00:00", "2019-04-03T00:00:00", "2019-04-04T00:00:00", "2019-04-04T00:00:00", "2019-04-05T00:00:00", "2019-04-05T00:00:00", "2019-04-06T00:00:00", "2019-04-07T00:00:00", "2019-04-08T00:00:00", "2019-04-09T00:00:00", "2019-04-10T00:00:00", "2019-04-11T00:00:00", "2019-04-12T00:00:00", "2019-04-13T00:00:00", "2019-04-15T00:00:00", "2019-04-16T00:00:00", "2019-04-17T00:00:00", "2019-04-18T00:00:00", "2019-04-19T00:00:00", "2019-04-20T00:00:00", "2019-04-21T00:00:00", "2019-04-22T00:00:00", "2019-04-23T00:00:00", "2019-04-24T00:00:00", "2019-04-25T00:00:00", "2019-04-26T00:00:00", "2019-04-27T00:00:00", "2019-04-28T00:00:00", "2019-04-29T00:00:00", "2019-04-30T00:00:00", "2019-05-01T00:00:00", "2019-05-02T00:00:00", "2019-05-03T00:00:00", "2019-05-04T00:00:00", "2019-05-05T00:00:00", "2019-05-06T00:00:00", "2019-05-07T00:00:00", "2019-05-08T00:00:00", "2019-05-09T00:00:00", "2019-05-10T00:00:00", "2019-05-11T00:00:00", "2019-05-12T00:00:00", "2019-05-13T00:00:00", "2019-05-14T00:00:00", "2019-05-15T00:00:00", "2019-05-16T00:00:00", "2019-05-17T00:00:00", "2019-05-18T00:00:00", "2019-05-19T00:00:00", "2019-05-20T00:00:00", "2019-05-21T00:00:00", "2019-05-22T00:00:00", "2019-05- ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-00a2e9307cf3> in <module>
#      32 fig.update_layout(width=1500,height=2500,showlegend=False)
#      33 fig.show()
# ---> 34 fig.write_image(f'images/19vs20_allcities.png')
#
# ~/miniconda3/lib/python3.8/site-packages/plotly/basedatatypes.py in write_image(self, *args, **kwargs)
#    3804         import plotly.io as pio
#    3805
# -> 3806         return pio.write_image(self, *args, **kwargs)
#    3807
#    3808     # Static helpers
#
# ~/miniconda3/lib/python3.8/site-packages/plotly/io/_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     243     # -------------
#     244     # Do this first so we don't create a file if image conversion fails
# --> 245     img_data = to_image(
#     246         fig,
#     247         format=format,
#
# ~/miniconda3/lib/python3.8/site-packages/plotly/io/_kaleido.py in to_image(fig, format, width, height, scale, validate, engine)
#     101         from ._orca import to_image as to_image_orca
#     102
# --> 103         return to_image_orca(
#     104             fig,
#     105             format=format,
#
# ~/miniconda3/lib/python3.8/site-packages/plotly/io/_orca.py in to_image(fig, format, width, height, scale, validate)
#    1533     # Make sure orca sever is running
#    1534     # -------------------------------
# -> 1535     ensure_server()
#    1536
#    1537     # Handle defaults
#
# ~/miniconda3/lib/python3.8/site-packages/plotly/io/_orca.py in ensure_server()
#    1359     # Validate psutil
#    1360     if psutil is None:
# -> 1361         raise ValueError(
#    1362             """\
#    1363 Image generation requires the psutil package.
#
# ValueError: Image generation requires the psutil package.
#
# Install using pip:
#     $ pip install psutil
#
# Install using conda:
#     $ conda install psutil

# %%
imp_pollutant

# %%
polmax
# Out:
# [410.0, 421.0, 30.7]
